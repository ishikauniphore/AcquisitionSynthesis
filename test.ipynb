# %%
lang = "JA_JP"

# %%
from datasets import load_dataset
import pandas as pd

ds = load_dataset("openai/MMMLU", lang)
df = ds['test'].shuffle().select(range(1000)).to_pandas()
questions = []
answers = []
for i, row in df.iterrows():
    questions.append(f"{row['Question']}\nA: {row['A']}\nB: {row['B']}\nC: {row['C']}\nD: {row['D']}")
    answers.append(row['Answer'])

pd.DataFrame.from_records({
    "questions": questions,
    "answers": answers
}).to_csv(f'data/mmmlu/{lang}.csv')
# Out:
# Generating test split: 100%|██████████| 14042/14042 [00:00<00:00, 95678.63 examples/s]

# %%
from datasets import load_dataset

ds = load_dataset("Helsinki-NLP/opus-100", "af-en")
df = ds['test'].shuffle().select(range(1000)).to_pandas()
# Out:
# ...
# Generating validation split: 100%|██████████| 2000/2000 [00:00<00:00, 813322.47 examples/s]

# %%
list(df['translation'])[0]
# Out:
# {'af': '- Nee, ek drink water', 'en': "- No, I'm on water."}

# %%
code = "de"
language = "German"

# %%
from datasets import load_dataset

ds = load_dataset("Helsinki-NLP/opus-100", f"{code}-en")
df = ds['test'].shuffle().select(range(1000)).to_pandas()
questions = []
answers = []
for row in list(df['translation']):
    questions.append(f"Translate the following from {language} to English: \"{row[code]}\"")
    answers.append(row['en'])

pd.DataFrame.from_records({
    "questions": questions,
    "answers": answers
}).to_csv(f'data/opus-100/{language}.csv')
# Out:
# ...
# Generating validation split: 100%|██████████| 2000/2000 [00:00<00:00, 632338.91 examples/s]

# %%
import pickle

with open('/home/ubuntu/AcquisitionSynthesis/evaluation/eval_Qwen2.5-7B-Instruct.pkl', 'rb') as f:
    exps = pickle.load(f)

# %%
len(exps[0]['embed_sim'])
# Out:
# 10

# %%
import pandas as pd
data = pd.read_parquet('/home/ubuntu/AcquisitionSynthesis/training_data/DataEnvGym_nemotron_stem_llama8bins.parquet')

# %%
data
# Out:
#                                                question  \
# 0     What is the most effective intervention to add...
# 1     Which statement about naloxegol is accurate: i...
# 2     A company is considering implementing a new po...
# 3     What is the most effective strategy for optimi...
# 4     What methodological approach would you use to ...
# ...                                                 ...
# 1146  What is the most effective approach for managi...
# 1147  A 30-year-old male presents with ankle pain af...
# 1148  A tendon undergoes cyclic loading where the lo...
# 1149  What theoretical framework most comprehensivel...
# 1150  Which of the following error sources contribut...
#
#                                               reasoning  \
# 0     To answer this question, one needs to analyze ...
# 1     This question targets the student's ability to...
# 2     To answer this question, the student needs to ...
# 3     The reasoning involves understanding the diaux...
# ...

# %%
data['reasoning'][0]
# Out:
# "To answer this question, one needs to analyze the relationship between the environment and health, identifying the key factors contributing to the health threats, such as the heat island effect, air pollution, and noise pollution. Then, evaluate the proposed interventions to determine which one addresses the integrated environmental exposure pathway by altering the built environment's role in amplifying multiple concurrent health threats."

# %%
import pandas as pd

# %%
dataset_name = "/home/ubuntu/AcquisitionSynthesis/data/nemotron_chat/test.parquet"

grounding_seed = pd.read_parquet(dataset_name, engine='pyarrow')
questions = list(grounding_seed.apply(lambda row: row['extra_info']['grounding_question'], axis=1))
answers = list(grounding_seed.apply(lambda row: row['extra_info']['grounding_answer'], axis=1))

# %%
questions
# Out:
# ['用地道的英语翻译“然而，当面对模锻件的残余应力场推断问题时”',
#  'Make programming implementation questions for the Filecoin project in a MCQ format with answers and concise explanations. Each MCQ should have at least three options, and each option should be different.',
#  "Écrire un email pour signaler que les piles d'un appareil reçu aujourd'hui ne fonctionnent pas demande à en recevoir ou bien je retourne l'appareil",
#  'how do you sort an array in python?',
#  'poor aunt jane,prim and plain是什么歌',
#  'Describe firewater',
# ...
